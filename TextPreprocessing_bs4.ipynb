# %% [markdown]
# ### Preprocessing Techniques on text data
#
# <!-- ![hugging face](https://www.thesoftwarereport.com/wp-content/uploads/2023/09/Hugging-Face2.png) -->
# - The example must contain at least 4 sentences.
# - Write about which text processing steps you might use for this task.
# - Support each step with a description of the technique and worked-out example.
# - The same example is to be used for each step, so choose the example carefully so that you will be able to demonstrate each step.

# %% [markdown]
# ##### 1. Importing Dependencies

# %%
import nltk
import os
import re
import math
import operator
from nltk import pos_tag, ne_chunk
from nltk.wsd import lesk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize,word_tokenize
from bs4 import BeautifulSoup # scrap up blog post from the web 
import requests # make over http calls over to web (to scrap up a page)
import json
from nltk.tree import Tree

# %%
# Download NLTK data
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\Harman\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
Stopwords = set(stopwords.words('english'))
wordlemmatizer = WordNetLemmatizer()

# %% [markdown]
# ##### 2. making web-scrapper

# %%
# URL = "https://hackernoon.com/simplifying-the-crazy-world-of-linux-distros"
URL = "https://medium.com/@palashm0002/understanding-the-basics-of-natural-language-processing-nlp-52b67cf954cb"
# URL = "https://hackernoon.com/nvidia-throws-gamers-under-the-bus"
# URL = "https://hackernoon.com/the-eggs-destined-to-give-birth-to-queens"

# %%
URL = input('Enter the URL: ')

# %%
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.text, 'html.parser')
results = soup.find_all(['h1', 'p'])
text = [result.text for result in results]
ARTICLE = ' '.join(text)
script_tag = soup.find('script', type='application/ld+json')

if script_tag:
    # Parse JSON data
    json_data = json.loads(script_tag.string)
    
    # Extract articleBody
    article_body = json_data.get('articleBody', '')

    print(article_body)

    ARTICLE = ARTICLE +". " + article_body
else:
    print("JSON-LD script tag not found.")
# Out:
# If you ever needed proof that Nvidia is no longer the company you think it is, look no further than the company&apos;s most recent GPU Technology Conference (also known as the GTC). The conference was chock-full of announcements, but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widely-in-demand, and equally as expensive, Hopper processors that have powered the likes of OpenAI&apos;s ChatGPT. It was the demand for the H100 chips that transformed Nvidia into a company worth over $2 trillion, almost overnight in the larger scheme of things, leading some (including HackerNoon) to question whether the stock was in a bubble (almost a quarter of HackerNoon readers thought that it was). But, as if Nvidia was out to prove everyone wrong, the company&apos;s last earnings release showed that not only was it still selling the Hopper processors, it was selling more of them and would continue to do so in the near future. Which brings us to the Nvidia GTC. Nvidia Chief Executive Jensen Huang is no Steve Jobs, but he is certainly a shareholders&apos; man, and he knows how to keep them happy – presentation skills be damned. The Blackwell announcement may be nothing akin to Apple&apos;s unveiling of the very first iPhone, but boy did Wall Street go crazy. And with crazy, comes worry. Worry about a monopoly. Worry about supply. Worry that the company may not be producing those darn AI processors fast enough. But for Nvidia, it is COVID-19 all over again: demand is up, consumers are desperate, and the company can charge whatever price it wants for its hardware. This, ladies and gentlemen, is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up. Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot: the enterprise. Because face it, the $40,000 H100 chips aren&apos;t for everyday consumers — they&apos;re for the faceless corporations that can dish out the billions needed to train large language models. And therein lies Nvidia&apos;s success. You see, just a day after the GTC began, Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the $250 billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer. Now all of this is well and good for the company, but there&apos;s one stakeholder that is hopelessly missing from all of Nvidia&apos;s future plans: the gamers. Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did. It started out as a company that produced graphic cards for video games, and for a long, long time, this is what Nvidia was known for. But as an offshoot of all the research it did in producing better and better graphic cards, it ended up creating tensor cores for real-time deep learning image enhancement and upscaling technologies for use in video games. Little did Nvidia know that this technology would then serve as the backbone of LLMs, instantly transforming it as the arms dealer of choice in corporations&apos; pursuit of the perfect AI. Nvidia may very well be out of touch with its roots, but that&apos;s hardly what shareholders care about. And if Nvidia shareholders don&apos;t care about the gamers, then Nvidia doesn&apos;t care about the gamers. This is why, a conference that should have been about the launch of the company&apos;s next graphic card was instantly hijacked by talk of AI, because it&apos;s 2024, and AI, for all intents and purposes, sells. Some may call it the &apos;Woodstock of AI&apos;, but I&apos;ll call it what it is: the death knell of Nvidia&apos;s days as a gaming-focused company. 👋 You’re reading HackerNoon&apos;s Tech Company News Brief ...
# AI is a data problem. Cyera is raising up to $300M on a $1.5B valuation to secure it — via TechCrunch
# 3 ways Apple’s monopoly lawsuit could change the iPhone experience for fans — via CNN
# Musk&apos;s X Corp loses lawsuit against hate speech watchdog — via Reuters
# Meta&apos;s broad-brush ban on Islamic term harmed free speech, board rules — via Axios
# Adam Neumann makes a $500 million bid for WeWork that could hit $900 million if financing and diligence firm up — via CNBC And that&apos;s a wrap! Don&apos;t forget to share this newsletter with your family and friends! See y&apos;all next week. PEACE! ☮️ — Sheharyar Khan, Editor, Business Tech @ HackerNoon *All rankings are current as of Monday. To see how the rankings have changed, please visit HackerNoon&apos;s Tech Company Rankings page. If you ever needed proof that Nvidia is no longer the company you think it is, look no further than the company&apos;s most recent GPU Technology Conference (also known as the GTC). The conference was chock-full of announcements, but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widely-in-demand, and equally as expensive, Hopper processors that have powered the likes of OpenAI&apos;s ChatGPT. Nvidia Nvidia It was the demand for the H100 chips that transformed Nvidia into a company worth over $2 trillion, almost overnight in the larger scheme of things, leading some (including HackerNoon) to question whether the stock was in a bubble (almost a quarter of HackerNoon readers thought that it was). But, as if Nvidia was out to prove everyone wrong, the company&apos;s last earnings release showed that not only was it still selling the Hopper processors, it was selling more of them and would continue to do so in the near future. question question more continue to do so continue to do so Which brings us to the Nvidia GTC. Nvidia Chief Executive Jensen Huang is no Steve Jobs, but he is certainly a shareholders&apos; man, and he knows how to keep them happy – presentation skills be damned. The Blackwell announcement may be nothing akin to Apple&apos;s unveiling of the very first iPhone, but boy did Wall Street go crazy. And with crazy, comes worry. Worry about a monopoly. Worry about supply. Worry that the company may not be producing those darn AI processors fast enough. But for Nvidia, it is COVID-19 all over again: demand is up, consumers are desperate, and the company can charge whatever price it wants for its hardware. This , ladies and gentlemen, is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up. This Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot: the enterprise. Because face it, the $40,000 H100 chips aren&apos;t for everyday consumers — they&apos;re for the faceless corporations that can dish out the billions needed to train large language models. And therein lies Nvidia&apos;s success. You see, just a day after the GTC began, Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the $250 billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer. meeting meeting Now all of this is well and good for the company, but there&apos;s one stakeholder that is hopelessly missing from all of Nvidia&apos;s future plans: the gamers. Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did. It started out as a company that produced graphic cards for video games, and for a long, long time, this is what Nvidia was known for. But as an offshoot of all the research it did in producing better and better graphic cards, it ended up creating tensor cores for real-time deep learning image enhancement and upscaling technologies for use in video games. Little did Nvidia know that this technology would then serve as the backbone of LLMs, instantly transforming it as the arms dealer of choice in corporations&apos; pursuit of the perfect AI. as Nvidia may very well be out of touch with its roots, but that&apos;s hardly what shareholder ...

# %%
print(ARTICLE)
# Out:
# Nvidia Throws Gamers Under the Bus If you ever needed proof that Nvidia is no longer the company you think it is, look no further than the company's most recent GPU Technology Conference (also known as the GTC). The conference was chock-full of announcements, but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widely-in-demand, and equally as expensive, Hopper processors that have powered the likes of OpenAI's ChatGPT.    It was the demand for the H100 chips that transformed Nvidia into a company worth over $2 trillion, almost overnight in the larger scheme of things, leading some (including HackerNoon) to question whether the stock was in a bubble (almost a quarter of HackerNoon readers thought that it was). But, as if Nvidia was out to prove everyone wrong, the company's last earnings release showed that not only was it still selling the Hopper processors, it was selling more of them and would continue to do so in the near future.    Which brings us to the Nvidia GTC. Nvidia Chief Executive Jensen Huang is no Steve Jobs, but he is certainly a shareholders' man, and he knows how to keep them happy – presentation skills be damned. The Blackwell announcement may be nothing akin to Apple's unveiling of the very first iPhone, but boy did Wall Street go crazy.    And with crazy, comes worry. Worry about a monopoly. Worry about supply. Worry that the company may not be producing those darn AI processors fast enough. But for Nvidia, it is COVID-19 all over again: demand is up, consumers are desperate, and the company can charge whatever price it wants for its hardware. This, ladies and gentlemen, is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up.    Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot: the enterprise. Because face it, the $40,000 H100 chips aren't for everyday consumers — they're for the faceless corporations that can dish out the billions needed to train large language models. And therein lies Nvidia's success.    You see, just a day after the GTC began, Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the $250 billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer.    Now all of this is well and good for the company, but there's one stakeholder that is hopelessly missing from all of Nvidia's future plans: the gamers.    Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did. It started out as a company that produced graphic cards for video games, and for a long, long time, this is what Nvidia was known for. But as an offshoot of all the research it did in producing better and better graphic cards, it ended up creating tensor cores for real-time deep learning image enhancement and upscaling technologies for use in video games. Little did Nvidia know that this technology would then serve as the backbone of LLMs, instantly transforming it as the arms dealer of choice in corporations' pursuit of the perfect AI.    Nvidia may very well be out of touch with its roots, but that's hardly what shareholders care about. And if Nvidia shareholders don't care about the gamers, then Nvidia doesn't care about the gamers. This is why, a conference that should have been about the launch of the company's next graphic card was instantly hijacked by talk of AI, because it's 2024, and AI, for all intents and purposes, sells.    Some may call it the 'Woodstock of AI', but I'll call it what it is: the death knell of Nvidia's days as a gaming-focused company.    How do you kill two birds with one stone? I don't know. Ask Satya Nadella.    So laser-focuse ...
# AI is a data problem. Cyera is raising up to $300M on a $1.5B valuation to secure it — via TechCrunch
# 3 ways Apple’s monopoly lawsuit could change the iPhone experience for fans — via CNN
# Musk&apos;s X Corp loses lawsuit against hate speech watchdog — via Reuters
# Meta&apos;s broad-brush ban on Islamic term harmed free speech, board rules — via Axios
# Adam Neumann makes a $500 million bid for WeWork that could hit $900 million if financing and diligence firm up — via CNBC And that&apos;s a wrap! Don&apos;t forget to share this newsletter with your family and friends! See y&apos;all next week. PEACE! ☮️ — Sheharyar Khan, Editor, Business Tech @ HackerNoon *All rankings are current as of Monday. To see how the rankings have changed, please visit HackerNoon&apos;s Tech Company Rankings page. If you ever needed proof that Nvidia is no longer the company you think it is, look no further than the company&apos;s most recent GPU Technology Conference (also known as the GTC). The conference was chock-full of announcements, but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widely-in-demand, and equally as expensive, Hopper processors that have powered the likes of OpenAI&apos;s ChatGPT. Nvidia Nvidia It was the demand for the H100 chips that transformed Nvidia into a company worth over $2 trillion, almost overnight in the larger scheme of things, leading some (including HackerNoon) to question whether the stock was in a bubble (almost a quarter of HackerNoon readers thought that it was). But, as if Nvidia was out to prove everyone wrong, the company&apos;s last earnings release showed that not only was it still selling the Hopper processors, it was selling more of them and would continue to do so in the near future. question question more continue to do so continue to do so Which brings us to the Nvidia GTC. Nvidia Chief Executive Jensen Huang is no Steve Jobs, but he is certainly a shareholders&apos; man, and he knows how to keep them happy – presentation skills be damned. The Blackwell announcement may be nothing akin to Apple&apos;s unveiling of the very first iPhone, but boy did Wall Street go crazy. And with crazy, comes worry. Worry about a monopoly. Worry about supply. Worry that the company may not be producing those darn AI processors fast enough. But for Nvidia, it is COVID-19 all over again: demand is up, consumers are desperate, and the company can charge whatever price it wants for its hardware. This , ladies and gentlemen, is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up. This Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot: the enterprise. Because face it, the $40,000 H100 chips aren&apos;t for everyday consumers — they&apos;re for the faceless corporations that can dish out the billions needed to train large language models. And therein lies Nvidia&apos;s success. You see, just a day after the GTC began, Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the $250 billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer. meeting meeting Now all of this is well and good for the company, but there&apos;s one stakeholder that is hopelessly missing from all of Nvidia&apos;s future plans: the gamers. Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did. It started out as a company that produced graphic cards for video games, and for a long, long time, this is what Nvidia was known for. But as an offshoot of all the research it did in producing better and better graphic cards, it ended up creating tensor cores for real-time deep learning image enhancement and upscaling technologies for use in video games. Little did Nvidia know that this technology would then serve as the backbone of LLMs, instantly transforming it as the arms dealer of choice in corporations&apos; pursuit of the perfect AI. as Nvidia may very well be out of touch with its roots, but that&apos;s hardly what shareholder ...

# %% [markdown]
# ##### 3. Data Cleaning Techniques
# - Noise Removal
# - Normalization
# - Sentence Segmentation
# - Tokenization
# - Stop-word Removal

# %%
def remove_noise(text):
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text

cleaned_text = remove_noise(ARTICLE)
print(cleaned_text)
# Out:
# Nvidia Throws Gamers Under the Bus If you ever needed proof that Nvidia is no longer the company you think it is look no further than the companys most recent GPU Technology Conference also known as the GTC The conference was chockfull of announcements but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widelyindemand and equally as expensive Hopper processors that have powered the likes of OpenAIs ChatGPT    It was the demand for the H chips that transformed Nvidia into a company worth over  trillion almost overnight in the larger scheme of things leading some including HackerNoon to question whether the stock was in a bubble almost a quarter of HackerNoon readers thought that it was But as if Nvidia was out to prove everyone wrong the companys last earnings release showed that not only was it still selling the Hopper processors it was selling more of them and would continue to do so in the near future    Which brings us to the Nvidia GTC Nvidia Chief Executive Jensen Huang is no Steve Jobs but he is certainly a shareholders man and he knows how to keep them happy  presentation skills be damned The Blackwell announcement may be nothing akin to Apples unveiling of the very first iPhone but boy did Wall Street go crazy    And with crazy comes worry Worry about a monopoly Worry about supply Worry that the company may not be producing those darn AI processors fast enough But for Nvidia it is COVID all over again demand is up consumers are desperate and the company can charge whatever price it wants for its hardware This ladies and gentlemen is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up    Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot the enterprise Because face it the  H chips arent for everyday consumers  theyre for the faceless corporations that can dish out the billions needed to train large language models And therein lies Nvidias success    You see just a day after the GTC began Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the  billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer    Now all of this is well and good for the company but theres one stakeholder that is hopelessly missing from all of Nvidias future plans the gamers    Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did It started out as a company that produced graphic cards for video games and for a long long time this is what Nvidia was known for But as an offshoot of all the research it did in producing better and better graphic cards it ended up creating tensor cores for realtime deep learning image enhancement and upscaling technologies for use in video games Little did Nvidia know that this technology would then serve as the backbone of LLMs instantly transforming it as the arms dealer of choice in corporations pursuit of the perfect AI    Nvidia may very well be out of touch with its roots but thats hardly what shareholders care about And if Nvidia shareholders dont care about the gamers then Nvidia doesnt care about the gamers This is why a conference that should have been about the launch of the companys next graphic card was instantly hijacked by talk of AI because its  and AI for all intents and purposes sells    Some may call it the Woodstock of AI but Ill call it what it is the death knell of Nvidias days as a gamingfocused company    How do you kill two birds with one stone I dont know Ask Satya Nadella    So laserfocused is the Microsoft chief executive on monopolizing his companys success in AI that he has decided to do the unthinkable hire its  ...
# AI is a data problem Cyera is raising up to M on a B valuation to secure it  via TechCrunch
#  ways Apples monopoly lawsuit could change the iPhone experience for fans  via CNN
# Muskaposs X Corp loses lawsuit against hate speech watchdog  via Reuters
# Metaaposs broadbrush ban on Islamic term harmed free speech board rules  via Axios
# Adam Neumann makes a  million bid for WeWork that could hit  million if financing and diligence firm up  via CNBC And thataposs a wrap Donapost forget to share this newsletter with your family and friends See yaposall next week PEACE   Sheharyar Khan Editor Business Tech  HackerNoon All rankings are current as of Monday To see how the rankings have changed please visit HackerNoonaposs Tech Company Rankings page If you ever needed proof that Nvidia is no longer the company you think it is look no further than the companyaposs most recent GPU Technology Conference also known as the GTC The conference was chockfull of announcements but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widelyindemand and equally as expensive Hopper processors that have powered the likes of OpenAIaposs ChatGPT Nvidia Nvidia It was the demand for the H chips that transformed Nvidia into a company worth over  trillion almost overnight in the larger scheme of things leading some including HackerNoon to question whether the stock was in a bubble almost a quarter of HackerNoon readers thought that it was But as if Nvidia was out to prove everyone wrong the companyaposs last earnings release showed that not only was it still selling the Hopper processors it was selling more of them and would continue to do so in the near future question question more continue to do so continue to do so Which brings us to the Nvidia GTC Nvidia Chief Executive Jensen Huang is no Steve Jobs but he is certainly a shareholdersapos man and he knows how to keep them happy  presentation skills be damned The Blackwell announcement may be nothing akin to Appleaposs unveiling of the very first iPhone but boy did Wall Street go crazy And with crazy comes worry Worry about a monopoly Worry about supply Worry that the company may not be producing those darn AI processors fast enough But for Nvidia it is COVID all over again demand is up consumers are desperate and the company can charge whatever price it wants for its hardware This  ladies and gentlemen is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up This Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot the enterprise Because face it the  H chips arenapost for everyday consumers  theyaposre for the faceless corporations that can dish out the billions needed to train large language models And therein lies Nvidiaaposs success You see just a day after the GTC began Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the  billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer meeting meeting Now all of this is well and good for the company but thereaposs one stakeholder that is hopelessly missing from all of Nvidiaaposs future plans the gamers Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did It started out as a company that produced graphic cards for video games and for a long long time this is what Nvidia was known for But as an offshoot of all the research it did in producing better and better graphic cards it ended up creating tensor cores for realtime deep learning image enhancement and upscaling technologies for use in video games Little did Nvidia know that this technology would then serve as the backbone of LLMs instantly transforming it as the arms dealer of choice in corporationsapos pursuit of the perfect AI as Nvidia may very well be out of touch with its roots but thataposs hardly what shareholders care about And if Nvidia shareholders donapost care about the gamers then Nvidia doesnapost care about the gamers This is why a conference t ...

# %%
def tokenize_sentence(text):
    return sent_tokenize(text)
tokens = tokenize_sentence(ARTICLE)
print(tokens)
# Out:
# ["Nvidia Throws Gamers Under the Bus If you ever needed proof that Nvidia is no longer the company you think it is, look no further than the company's most recent GPU Technology Conference (also known as the GTC).", "The conference was chock-full of announcements, but the big one was of course the unveiling of the Blackwell class of AI chips which are supposedly going to be better than the widely-in-demand, and equally as expensive, Hopper processors that have powered the likes of OpenAI's ChatGPT.", 'It was the demand for the H100 chips that transformed Nvidia into a company worth over $2 trillion, almost overnight in the larger scheme of things, leading some (including HackerNoon) to question whether the stock was in a bubble (almost a quarter of HackerNoon readers thought that it was).', "But, as if Nvidia was out to prove everyone wrong, the company's last earnings release showed that not only was it still selling the Hopper processors, it was selling more of them and would continue to do so in the near future.", 'Which brings us to the Nvidia GTC.', "Nvidia Chief Executive Jensen Huang is no Steve Jobs, but he is certainly a shareholders' man, and he knows how to keep them happy – presentation skills be damned.", "The Blackwell announcement may be nothing akin to Apple's unveiling of the very first iPhone, but boy did Wall Street go crazy.", 'And with crazy, comes worry.', 'Worry about a monopoly.', 'Worry about supply.', 'Worry that the company may not be producing those darn AI processors fast enough.', 'But for Nvidia, it is COVID-19 all over again: demand is up, consumers are desperate, and the company can charge whatever price it wants for its hardware.', 'This, ladies and gentlemen, is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up.', 'Which makes Nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot: the enterprise.', "Because face it, the $40,000 H100 chips aren't for everyday consumers — they're for the faceless corporations that can dish out the billions needed to train large language models.", "And therein lies Nvidia's success.", 'You see, just a day after the GTC began, Jensen Huang held a meeting with investors to tell them the company was poised to win a large chunk of the $250 billion corporations spend on building and maintaining data centers every year given the variety of hardware and software Nvidia has on offer.', "Now all of this is well and good for the company, but there's one stakeholder that is hopelessly missing from all of Nvidia's future plans: the gamers.", 'Nvidia never really started as an artificial intelligence company the way OpenAI and so many others like it did.', 'It started out as a company that produced graphic cards for video games, and for a long, long time, this is what Nvidia was known for.', 'But as an offshoot of all the research it did in producing better and better graphic cards, it ended up creating tensor cores for real-time deep learning image enhancement and upscaling technologies for use in video games.', "Little did Nvidia know that this technology would then serve as the backbone of LLMs, instantly transforming it as the arms dealer of choice in corporations' pursuit of the perfect AI.", "Nvidia may very well be out of touch with its roots, but that's hardly what shareholders care about.", "And if Nvidia shareholders don't care about the gamers, then Nvidia doesn't care about the gamers.", "This is why, a conference that should have been about the launch of the company's next graphic card was instantly hijacked by talk of AI, because it's 2024, and AI, for all intents and purposes, sells.", "Some may call it the 'Woodstock of AI', but I'll call it what it is: the death knell of Nvidia's days as a gaming-focused company.", 'How do you kill two birds with one stone?', ...

# %%
def normalize_text(text):
    return text.lower()

normalized_text = normalize_text(cleaned_text)
print(normalized_text)
# Out:
# nvidia throws gamers under the bus if you ever needed proof that nvidia is no longer the company you think it is look no further than the companys most recent gpu technology conference also known as the gtc the conference was chockfull of announcements but the big one was of course the unveiling of the blackwell class of ai chips which are supposedly going to be better than the widelyindemand and equally as expensive hopper processors that have powered the likes of openais chatgpt    it was the demand for the h chips that transformed nvidia into a company worth over  trillion almost overnight in the larger scheme of things leading some including hackernoon to question whether the stock was in a bubble almost a quarter of hackernoon readers thought that it was but as if nvidia was out to prove everyone wrong the companys last earnings release showed that not only was it still selling the hopper processors it was selling more of them and would continue to do so in the near future    which brings us to the nvidia gtc nvidia chief executive jensen huang is no steve jobs but he is certainly a shareholders man and he knows how to keep them happy  presentation skills be damned the blackwell announcement may be nothing akin to apples unveiling of the very first iphone but boy did wall street go crazy    and with crazy comes worry worry about a monopoly worry about supply worry that the company may not be producing those darn ai processors fast enough but for nvidia it is covid all over again demand is up consumers are desperate and the company can charge whatever price it wants for its hardware this ladies and gentlemen is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up    which makes nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot the enterprise because face it the  h chips arent for everyday consumers  theyre for the faceless corporations that can dish out the billions needed to train large language models and therein lies nvidias success    you see just a day after the gtc began jensen huang held a meeting with investors to tell them the company was poised to win a large chunk of the  billion corporations spend on building and maintaining data centers every year given the variety of hardware and software nvidia has on offer    now all of this is well and good for the company but theres one stakeholder that is hopelessly missing from all of nvidias future plans the gamers    nvidia never really started as an artificial intelligence company the way openai and so many others like it did it started out as a company that produced graphic cards for video games and for a long long time this is what nvidia was known for but as an offshoot of all the research it did in producing better and better graphic cards it ended up creating tensor cores for realtime deep learning image enhancement and upscaling technologies for use in video games little did nvidia know that this technology would then serve as the backbone of llms instantly transforming it as the arms dealer of choice in corporations pursuit of the perfect ai    nvidia may very well be out of touch with its roots but thats hardly what shareholders care about and if nvidia shareholders dont care about the gamers then nvidia doesnt care about the gamers this is why a conference that should have been about the launch of the companys next graphic card was instantly hijacked by talk of ai because its  and ai for all intents and purposes sells    some may call it the woodstock of ai but ill call it what it is the death knell of nvidias days as a gamingfocused company    how do you kill two birds with one stone i dont know ask satya nadella    so laserfocused is the microsoft chief executive on monopolizing his companys success in ai that he has decided to do the unthinkable hire its  ...
# ai is a data problem cyera is raising up to m on a b valuation to secure it  via techcrunch
#  ways apples monopoly lawsuit could change the iphone experience for fans  via cnn
# muskaposs x corp loses lawsuit against hate speech watchdog  via reuters
# metaaposs broadbrush ban on islamic term harmed free speech board rules  via axios
# adam neumann makes a  million bid for wework that could hit  million if financing and diligence firm up  via cnbc and thataposs a wrap donapost forget to share this newsletter with your family and friends see yaposall next week peace   sheharyar khan editor business tech  hackernoon all rankings are current as of monday to see how the rankings have changed please visit hackernoonaposs tech company rankings page if you ever needed proof that nvidia is no longer the company you think it is look no further than the companyaposs most recent gpu technology conference also known as the gtc the conference was chockfull of announcements but the big one was of course the unveiling of the blackwell class of ai chips which are supposedly going to be better than the widelyindemand and equally as expensive hopper processors that have powered the likes of openaiaposs chatgpt nvidia nvidia it was the demand for the h chips that transformed nvidia into a company worth over  trillion almost overnight in the larger scheme of things leading some including hackernoon to question whether the stock was in a bubble almost a quarter of hackernoon readers thought that it was but as if nvidia was out to prove everyone wrong the companyaposs last earnings release showed that not only was it still selling the hopper processors it was selling more of them and would continue to do so in the near future question question more continue to do so continue to do so which brings us to the nvidia gtc nvidia chief executive jensen huang is no steve jobs but he is certainly a shareholdersapos man and he knows how to keep them happy  presentation skills be damned the blackwell announcement may be nothing akin to appleaposs unveiling of the very first iphone but boy did wall street go crazy and with crazy comes worry worry about a monopoly worry about supply worry that the company may not be producing those darn ai processors fast enough but for nvidia it is covid all over again demand is up consumers are desperate and the company can charge whatever price it wants for its hardware this  ladies and gentlemen is the future tech companies had hoped for when they began aggressively hiring during the worldwide pandemic only to find demand normalizing once the world opened up this which makes nvidia quite possibly the only company to not only have profiteered off of consumers during the pandemic but to have hit an even bigger jackpot the enterprise because face it the  h chips arenapost for everyday consumers  theyaposre for the faceless corporations that can dish out the billions needed to train large language models and therein lies nvidiaaposs success you see just a day after the gtc began jensen huang held a meeting with investors to tell them the company was poised to win a large chunk of the  billion corporations spend on building and maintaining data centers every year given the variety of hardware and software nvidia has on offer meeting meeting now all of this is well and good for the company but thereaposs one stakeholder that is hopelessly missing from all of nvidiaaposs future plans the gamers nvidia never really started as an artificial intelligence company the way openai and so many others like it did it started out as a company that produced graphic cards for video games and for a long long time this is what nvidia was known for but as an offshoot of all the research it did in producing better and better graphic cards it ended up creating tensor cores for realtime deep learning image enhancement and upscaling technologies for use in video games little did nvidia know that this technology would then serve as the backbone of llms instantly transforming it as the arms dealer of choice in corporationsapos pursuit of the perfect ai as nvidia may very well be out of touch with its roots but thataposs hardly what shareholders care about and if nvidia shareholders donapost care about the gamers then nvidia doesnapost care about the gamers this is why a conference t ...

# %%
def tokenize_text(text):
    return word_tokenize(text)
tokens = tokenize_text(normalized_text)
print(tokens)
# Out:
# ['nvidia', 'throws', 'gamers', 'under', 'the', 'bus', 'if', 'you', 'ever', 'needed', 'proof', 'that', 'nvidia', 'is', 'no', 'longer', 'the', 'company', 'you', 'think', 'it', 'is', 'look', 'no', 'further', 'than', 'the', 'companys', 'most', 'recent', 'gpu', 'technology', 'conference', 'also', 'known', 'as', 'the', 'gtc', 'the', 'conference', 'was', 'chockfull', 'of', 'announcements', 'but', 'the', 'big', 'one', 'was', 'of', 'course', 'the', 'unveiling', 'of', 'the', 'blackwell', 'class', 'of', 'ai', 'chips', 'which', 'are', 'supposedly', 'going', 'to', 'be', 'better', 'than', 'the', 'widelyindemand', 'and', 'equally', 'as', 'expensive', 'hopper', 'processors', 'that', 'have', 'powered', 'the', 'likes', 'of', 'openais', 'chatgpt', 'it', 'was', 'the', 'demand', 'for', 'the', 'h', 'chips', 'that', 'transformed', 'nvidia', 'into', 'a', 'company', 'worth', 'over', 'trillion', 'almost', 'overnight', 'in', 'the', 'larger', 'scheme', 'of', 'things', 'leading', 'some', 'including', 'hackernoon', 'to', 'question', 'whether', 'the', 'stock', 'was', 'in', 'a', 'bubble', 'almost', 'a', 'quarter', 'of', 'hackernoon', 'readers', 'thought', 'that', 'it', 'was', 'but', 'as', 'if', 'nvidia', 'was', 'out', 'to', 'prove', 'everyone', 'wrong', 'the', 'companys', 'last', 'earnings', 'release', 'showed', 'that', 'not', 'only', 'was', 'it', 'still', 'selling', 'the', 'hopper', 'processors', 'it', 'was', 'selling', 'more', 'of', 'them', 'and', 'would', 'continue', 'to', 'do', 'so', 'in', 'the', 'near', 'future', 'which', 'brings', 'us', 'to', 'the', 'nvidia', 'gtc', 'nvidia', 'chief', 'executive', 'jensen', 'huang', 'is', 'no', 'steve', 'jobs', 'but', 'he', 'is', 'certainly', 'a', 'shareholders', 'man', 'and', 'he', 'knows', 'how', 'to', 'keep', 'them', 'happy', 'presentation', 'skills', 'be', 'damned', 'the', 'blackwell', 'announcement', 'may', 'be', 'nothing', 'akin', 'to', 'apples', 'unveiling', 'of', 'the', 'very', 'first', 'iphone', 'but', 'boy', 'did', 'wall', 'street', 'go', 'crazy', 'and', 'with', 'crazy', 'comes', 'worry', 'worry', 'about', 'a', 'monopoly', 'worry', 'about', 'supply', 'worry', 'that', 'the', 'company', 'may', 'not', 'be', 'producing', 'those', 'darn', 'ai', 'processors', 'fast', 'enough', 'but', 'for', 'nvidia', 'it', 'is', 'covid', 'all', 'over', 'again', 'demand', 'is', 'up', 'consumers', 'are', 'desperate', 'and', 'the', 'company', 'can', 'charge', 'whatever', 'price', 'it', 'wants', 'for', 'its', 'hardware', 'this', 'ladies', 'and', 'gentlemen', 'is', 'the', 'future', 'tech', 'companies', 'had', 'hoped', 'for', 'when', 'they', 'began', 'aggressively', 'hiring', 'during', 'the', 'worldwide', 'pandemic', 'only', 'to', 'find', 'demand', 'normalizing', 'once', 'the', 'world', 'opened', 'up', 'which', 'makes', 'nvidia', 'quite', 'possibly', 'the', 'only', 'company', 'to', 'not', 'only', 'have', 'profiteered', 'off', 'of', 'consumers', 'during', 'the', 'pandemic', 'but', 'to', 'have', 'hit', 'an', 'even', 'bigger', 'jackpot', 'the', 'enterprise', 'because', 'face', 'it', 'the', 'h', 'chips', 'arent', 'for', 'everyday', 'consumers', 'theyre', 'for', 'the', 'faceless', 'corporations', 'that', 'can', 'dish', 'out', 'the', 'billions', 'needed', 'to', 'train', 'large', 'language', 'models', 'and', 'therein', 'lies', 'nvidias', 'success', 'you', 'see', 'just', 'a', 'day', 'after', 'the', 'gtc', 'began', 'jensen', 'huang', 'held', 'a', 'meeting', 'with', 'investors', 'to', 'tell', 'them', 'the', 'company', 'was', 'poised', 'to', 'win', 'a', 'large', 'chunk', 'of', 'the', 'billion', 'corporations', 'spend', 'on', 'building', 'and', 'maintaining', 'data', 'centers', 'every', 'year', 'given', 'the', 'variety', 'of', 'hardware', 'and', 'software', 'nvidia', 'has', 'on', 'offer', 'now', 'all', 'of', 'this', 'is', 'well', 'and', 'good', 'for', 'the', 'company', 'but', 'theres', 'one', 'stakeholder', 'that', 'is', 'hopelessly', 'missing', 'from', 'all', 'of', 'nvidias', 'future', 'plans', 'the', 'gamers', 'nvidia', 'never', 'really', 'started ...

# %%
tokens
# Out:
# ['nvidia',
#  'throws',
#  'gamers',
#  'under',
#  'the',
#  'bus',
#  'if',
#  'you',
#  'ever',
#  'needed',
#  'proof',
#  'that',
#  'nvidia',
#  'is',
#  'no',
#  'longer',
#  'the',
#  'company',
#  'you',
#  'think',
#  'it',
#  'is',
#  'look',
#  'no',
#  'further',
#  'than',
#  'the',
#  'companys',
#  'most',
#  'recent',
#  'gpu',
#  'technology',
#  'conference',
#  'also',
#  'known',
#  'as',
#  'the',
#  'gtc',
#  'the',
#  'conference',
#  'was',
#  'chockfull',
#  'of',
#  'announcements',
#  'but',
#  'the',
#  'big',
#  'one',
#  'was',
#  'of',
#  'course',
#  'the',
#  'unveiling',
#  'of',
#  'the',
#  'blackwell',
#  'class',
#  'of',
#  'ai',
#  'chips',
#  'which',
#  'are',
#  'supposedly',
#  'going',
#  'to',
#  'be',
#  'better',
#  'than',
#  'the',
#  'widelyindemand',
#  'and',
#  'equally',
#  'as',
#  'expensive',
#  'hopper',
#  'processors',
#  'that',
#  'have',
#  'powered',
#  'the',
#  'likes',
#  'of',
#  'openais',
#  'chatgpt',
#  'it',
#  'was',
#  'the',
#  'demand',
#  'for',
#  'the',
#  'h',
#  'chips',
#  'that',
#  'transformed',
#  'nvidia',
#  'into',
#  'a',
#  'company',
#  'worth',
#  'over',
#  'trillion',
#  'almost',
#  'overnight',
#  'in',
#  'the',
#  'larger',
#  'scheme',
#  'of',
#  'things',
#  'leading',
#  'some',
#  'including',
#  'hackernoon',
#  'to',
#  'question',
#  'whether',
#  'the',
#  'stock',
#  'was',
#  'in',
#  'a',
#  'bubble',
#  'almost',
#  'a',
#  'quarter',
#  'of',
#  'hackernoon',
#  'readers',
#  'thought',
#  'that',
#  'it',
#  'was',
#  'but',
#  'as',
#  'if',
#  'nvidia',
#  'was',
#  'out',
#  'to',
#  'prove',
#  'everyone',
#  'wrong',
#  'the',
#  'companys',
#  'last',
#  'earnings',
#  'release',
#  'showed',
#  'that',
#  'not',
#  'only',
#  'was',
#  'it',
#  'still',
#  'selling',
#  'the',
#  'hopper',
#  'processors',
#  'it',
#  'was',
#  'selling',
#  'more',
#  'of',
#  'them',
#  'and',
#  'would',
#  'continue',
#  'to',
#  'do',
#  'so',
#  'in',
#  'the',
#  'near',
#  'future',
#  'which',
#  'brings',
#  'us',
#  'to',
#  'the',
#  'nvidia',
#  'gtc',
#  'nvidia',
#  'chief',
#  'executive',
#  'jensen',
#  'huang',
#  'is',
#  'no',
#  'steve',
#  'jobs',
#  'but',
#  'he',
#  'is',
#  'certainly',
#  'a',
#  'shareholders',
#  'man',
#  'and',
#  'he',
#  'knows',
#  'how',
#  'to',
#  'keep',
#  'them',
#  'happy',
#  'presentation',
#  'skills',
#  'be',
#  'damned',
#  'the',
#  'blackwell',
#  'announcement',
#  'may',
#  'be',
#  'nothing',
#  'akin',
#  'to',
#  'apples',
#  'unveiling',
#  'of',
#  'the',
#  'very',
#  'first',
#  'iphone',
#  'but',
#  'boy',
#  'did',
#  'wall',
#  'street',
#  'go',
#  'crazy',
#  'and',
#  'with',
#  'crazy',
#  'comes',
#  'worry',
#  'worry',
#  'about',
#  'a',
#  'monopoly',
#  'worry',
#  'about',
#  'supply',
#  'worry',
#  'that',
#  'the',
#  'company',
#  'may',
#  'not',
#  'be',
#  'producing',
#  'those',
#  'darn',
#  'ai',
#  'processors',
#  'fast',
#  'enough',
#  'but',
#  'for',
#  'nvidia',
#  'it',
#  'is',
#  'covid',
#  'all',
#  'over',
#  'again',
#  'demand',
#  'is',
#  'up',
#  'consumers',
#  'are',
#  'desperate',
#  'and',
#  'the',
#  'company',
#  'can',
#  'charge',
#  'whatever',
#  'price',
#  'it',
#  'wants',
#  'for',
#  'its',
#  'hardware',
#  'this',
#  'ladies',
#  'and',
#  'gentlemen',
#  'is',
#  'the',
#  'future',
#  'tech',
#  'companies',
#  'had',
#  'hoped',
#  'for',
#  'when',
#  'they',
#  'began',
#  'aggressively',
#  'hiring',
#  'during',
#  'the',
#  'worldwide',
#  'pandemic',
#  'only',
#  'to',
#  'find',
#  'demand',
#  'normalizing',
#  'once',
#  'the',
#  'world',
#  'opened',
#  'up',
#  'which',
#  'makes',
#  'nvidia',
#  'quite',
#  'possibly',
#  'the',
#  'only',
#  'company',
#  'to',
#  'not',
#  'only',
#  'have',
#  'profiteered',
#  'off',
#  'of',
#  'consumers',
#  'during',
#  'the',
#  'pandemic',
#  'but',
#  'to',
#  'have',
#  'hit',
#  'an',
#  'even',
#  'bigger',
#  'jackpot',
#  'the',
#  'enterprise',
#  'because',
#  'face',
#  'it',
#  'the',
#  'h',
#  'chips',
#  'arent',
#  'for',
#  'everyday',
#  'consumers',
#  'theyre',
#  'for',
#  'the',
#  'faceless',
#  'corporations',
#  'that',
#  'can',
#  'dish',
#  'out',
#  'the',
#  'billions',
#  'needed',
#  'to',
#  'train',
#  'large',
#  'language',
#  'models',
#  'and',
#  'therein',
#  'lies',
#  'nvidias',
#  'success',
#  'you',
#  'see',
#  'just',
#  'a',
#  'day',
#  'after',
#  'the',
#  'gtc',
#  'began',
#  'jensen',
#  'huang',
#  'held',
#  'a',
#  'meeting',
#  'with',
#  'investors',
#  'to',
#  'tell',
#  'them',
#  'the',
#  'company',
#  'was',
#  'poised',
#  'to',
#  'win',
#  'a',
#  'large',
#  'chunk',
#  'of',
#  'the',
#  'billion',
#  'corporations',
#  'spend',
#  'on',
#  'building',
#  'and',
#  'maintaining',
#  'data',
#  'centers',
#  'every',
#  'year',
#  'given',
#  'the',
#  'variety',
#  'of',
#  'hardware',
#  'and',
#  'software',
#  'nvidia',
#  'has',
#  'on',
#  'offer',
#  'now',
#  'all',
#  'of',
#  'this',
#  'is',
#  'well',
#  'and',
#  'good',
#  'for',
#  'the',
#  'company',
#  'but',
#  'theres',
#  'one',
#  'stakeholder',
#  'that',
#  'is',
#  'hopelessly',
#  'missing',
#  'from',
#  'all',
#  'of',
#  'nvidias',
#  'future',
#  'plans',
#  'the',
#  'gamers',
#  'nvidia',
#  'never',
#  'really',
#  'started',
#  'as',
#  'an',
#  'artificial',
#  'intelligence',
#  'company',
#  'the',
#  'way',
#  'openai',
#  'and',
#  'so',
#  'many',
#  'others',
#  'like',
#  'it',
#  'did',
#  'it',
#  'started',
#  'out',
#  'as',
#  'a',
#  'company',
#  'that',
#  'produced',
#  'graphic',
#  'cards',
#  'for',
#  'video',
#  'games',
#  'and',
#  'for',
#  'a',
#  'long',
#  'long',
#  'time',
#  'this',
#  'is',
#  'what',
#  'nvidia',
#  'was',
#  'known',
#  'for',
#  'but',
#  'as',
#  'an',
#  'offshoot',
#  'of',
#  'all',
#  'the',
#  'research',
#  'it',
#  'did',
#  'in',
#  'producing',
#  'better',
#  'and',
#  'better',
#  'graphic',
#  'cards',
#  'it',
#  'ended',
#  'up',
#  'creating',
#  'tensor',
#  'cores',
#  'for',
#  'realtime',
#  'deep',
#  'learning',
#  'image',
#  'enhancement',
#  'and',
#  'upscaling',
#  'technologies',
#  'for',
#  'use',
#  'in',
#  'video',
#  'games',
#  'little',
#  'did',
#  'nvidia',
#  'know',
#  'that',
#  'this',
#  'technology',
#  'would',
#  'then',
#  'serve',
#  'as',
#  'the',
#  'backbone',
#  'of',
#  'llms',
#  'instantly',
#  'transforming',
#  'it',
#  'as',
#  'the',
#  'arms',
#  'dealer',
#  'of',
#  'choice',
#  'in',
#  'corporations',
#  'pursuit',
#  'of',
#  'the',
#  'perfect',
#  'ai',
#  'nvidia',
#  'may',
#  'very',
#  'well',
#  'be',
#  'out',
#  'of',
#  'touch',
#  'with',
#  'its',
#  'roots',
#  'but',
#  'thats',
#  'hardly',
#  'what',
#  'shareholders',
#  'care',
#  'about',
#  'and',
#  'if',
#  'nvidia',
#  'shareholders',
#  'dont',
#  'care',
#  'about',
#  'the',
#  'gamers',
#  'then',
#  'nvidia',
#  'doesnt',
#  'care',
#  'about',
#  'the',
#  'gamers',
#  'this',
#  'is',
#  'why',
#  'a',
#  'conference',
#  'that',
#  'should',
#  'have',
#  'been',
#  'about',
#  'the',
#  'launch',
#  'of',
#  'the',
#  'companys',
#  'next',
#  'graphic',
#  'card',
#  'was',
#  'instantly',
#  'hijacked',
#  'by',
#  'talk',
#  'of',
#  'ai',
#  'because',
#  'its',
#  'and',
#  'ai',
#  'for',
#  'all',
#  'intents',
#  'and',
#  'purposes',
#  'sells',
#  'some',
#  'may',
#  'call',
#  'it',
#  'the',
#  'woodstock',
#  'of',
#  'ai',
#  'but',
#  'ill',
#  'call',
#  'it',
#  'what',
#  'it',
#  'is',
#  'the',
#  'death',
#  'knell',
#  'of',
#  'nvidias',
#  'days',
#  'as',
#  'a',
#  'gamingfocused',
#  'company',
#  'how',
#  'do',
#  'you',
#  'kill',
#  'two',
#  'birds',
#  'with',
#  'one',
#  'stone',
#  'i',
#  'dont',
#  'know',
#  'ask',
#  'satya',
#  'nadella',
#  'so',
#  'laserfocused',
#  'is',
#  'the',
#  'microsoft',
#  'chief',
#  'executive',
#  'on',
#  'monopolizing',
#  'his',
#  'companys',
#  'success',
#  'in',
#  'ai',
#  'that',
#  'he',
#  'has',
#  'decided',
#  'to',
#  'do',
#  'the',
#  'unthinkable',
#  'hire',
#  'its',
#  'competitors',
#  'staff',
#  'and',
#  'hand',
#  'them',
#  'the',
#  'reins',
#  'of',
#  'a',
#  'newly',
#  'launched',
#  'division',
#  'focused',
#  'primarily',
#  'on',
#  'artificial',
#  'intelligence',
#  'i',
#  'am',
#  'of',
#  'course',
#  'referring',
#  'to',
#  'mustafa',
#  'suleyman',
#  'and',
#  'karen',
#  'simonyan',
#  'the',
#  'cofounders',
#  'of',
#  'ai',
#  'startup',
#  'inflection',
#  'ai',
#  'which',
#  'up',
#  'until',
#  'recently',
#  'should',
#  'have',
#  'been',
#  'competing',
#  'against',
#  'microsofts',
#  'ward',
#  'openai',
#  'but',
#  'found',
#  'itself',
#  'with',
#  'an',
#  'offer',
#  'i',
#  'assume',
#  'they',
#  'could',
#  'not',
#  'refuse',
#  'yes',
#  'the',
#  'very',
#  'same',
#  'mustafa',
#  'suleyman',
#  'who',
#  'cofounded',
#  'deepmind',
#  'technologies',
#  'and',
#  'sold',
#  'it',
#  'to',
#  'google',
#  'in',
#  'will',
#  'be',
#  'leading',
#  'microsoft',
#  'ai',
#  'as',
#  'its',
#  'chief',
#  'executive',
#  'with',
#  'the',
#  'help',
#  'of',
#  'karen',
#  'simonyan',
#  'as',
#  'the',
#  'divisions',
#  'chief',
#  'scientist',
#  'microsoft',
#  'also',
#  'seems',
#  'to',
#  'have',
#  'hired',
#  'several',
#  'members',
#  'of',
#  'the',
#  'inflection',
#  'team',
#  'who',
#  'have',
#  'chosen',
#  'to',
#  'join',
#  'suleyman',
#  'and',
#  'simonyan',
#  'to',
#  'advance',
#  'the',
#  'companys',
#  'copilot',
#  'and',
#  'other',
#  'consumer',
#  'ai',
#  'products',
#  'and',
#  'research',
#  'so',
#  'what',
#  'does',
#  'inflection',
#  'ai',
#  'get',
#  'in',
#  'return',
#  'a',
#  'whopping',
#  'million',
#  'apparently',
#  'and',
#  'the',
#  'prestige',
#  'of',
#  'working',
#  'with',
#  'microsoft',
#  'thats',
#  'a',
#  'lot',
#  'of',
#  'money',
#  'to',
#  'pay',
#  'to',
#  'get',
#  'your',
#  'competitor',
#  'out',
#  'of',
#  'the',
#  'way',
#  'and',
#  'keep',
#  'openai',
#  'and',
#  'by',
#  'extension',
#  'sam',
#  'altman',
#  'in',
#  'check',
#  'but',
#  'as',
#  'the',
#  'worlds',
#  'most',
#  'valuable',
#  'company',
#  'right',
#  'now',
#  'microsoft',
#  'can',
#  'probably',
#  'get',
#  'away',
#  'with',
#  'just',
#  'about',
#  'anything',
#  'microsoft',
#  'ranked',
#  'on',
#  'hackernoons',
#  'tech',
#  'company',
#  'rankingsthis',
#  'week',
#  'google',
#  'was',
#  'on',
#  'the',
#  'spot',
#  'first',
#  'the',
#  'electric',
#  'car',
#  'now',
#  'the',
#  'smartwatch',
#  'displays',
#  'in',
#  'perhaps',
#  'what',
#  'is',
#  'a',
#  'period',
#  'of',
#  'realignment',
#  'for',
#  'apple',
#  'the',
#  'company',
#  'has',
#  'pulled',
#  'the',
#  'plug',
#  'on',
#  'building',
#  'its',
#  'own',
#  'smartwatch',
#  'displays',
#  'due',
#  'to',
#  'the',
#  'cost',
#  'and',
#  'complexity',
#  'involved',
#  'the',
#  'microled',
#  'displays',
#  'were',
#  'due',
#  'to',
#  'be',
#  'introduced',
#  'in',
#  'a',
#  'future',
#  'version',
#  'of',
#  'the',
#  'apple',
#  'watch',
#  'and',
#  'were',
#  'part',
#  'of',
#  'a',
#  'push',
#  'to',
#  'lower',
#  'the',
#  'companys',
#  'reliance',
#  'on',
#  'partners',
#  'but',
#  'it',
#  'seems',
#  'the',
#  'company',
#  'is',
#  'no',
#  'longer',
#  'planning',
#  'to',
#  'design',
#  'and',
#  'develop',
#  'that',
#  'technology',
#  'in',
#  'house',
#  'maybe',
#  'focusing',
#  'instead',
#  'on',
#  'the',
#  'newly',
#  'launched',
#  'and',
#  'confusingly',
#  'reviewed',
#  'apple',
#  'vision',
#  'pros',
#  'as',
#  ...]

# %%
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    return [word for word in tokens if word not in stop_words]

filtered_tokens = remove_stopwords(tokens)
print(filtered_tokens)
# Out:
# ['nvidia', 'throws', 'gamers', 'bus', 'ever', 'needed', 'proof', 'nvidia', 'longer', 'company', 'think', 'look', 'companys', 'recent', 'gpu', 'technology', 'conference', 'also', 'known', 'gtc', 'conference', 'chockfull', 'announcements', 'big', 'one', 'course', 'unveiling', 'blackwell', 'class', 'ai', 'chips', 'supposedly', 'going', 'better', 'widelyindemand', 'equally', 'expensive', 'hopper', 'processors', 'powered', 'likes', 'openais', 'chatgpt', 'demand', 'h', 'chips', 'transformed', 'nvidia', 'company', 'worth', 'trillion', 'almost', 'overnight', 'larger', 'scheme', 'things', 'leading', 'including', 'hackernoon', 'question', 'whether', 'stock', 'bubble', 'almost', 'quarter', 'hackernoon', 'readers', 'thought', 'nvidia', 'prove', 'everyone', 'wrong', 'companys', 'last', 'earnings', 'release', 'showed', 'still', 'selling', 'hopper', 'processors', 'selling', 'would', 'continue', 'near', 'future', 'brings', 'us', 'nvidia', 'gtc', 'nvidia', 'chief', 'executive', 'jensen', 'huang', 'steve', 'jobs', 'certainly', 'shareholders', 'man', 'knows', 'keep', 'happy', 'presentation', 'skills', 'damned', 'blackwell', 'announcement', 'may', 'nothing', 'akin', 'apples', 'unveiling', 'first', 'iphone', 'boy', 'wall', 'street', 'go', 'crazy', 'crazy', 'comes', 'worry', 'worry', 'monopoly', 'worry', 'supply', 'worry', 'company', 'may', 'producing', 'darn', 'ai', 'processors', 'fast', 'enough', 'nvidia', 'covid', 'demand', 'consumers', 'desperate', 'company', 'charge', 'whatever', 'price', 'wants', 'hardware', 'ladies', 'gentlemen', 'future', 'tech', 'companies', 'hoped', 'began', 'aggressively', 'hiring', 'worldwide', 'pandemic', 'find', 'demand', 'normalizing', 'world', 'opened', 'makes', 'nvidia', 'quite', 'possibly', 'company', 'profiteered', 'consumers', 'pandemic', 'hit', 'even', 'bigger', 'jackpot', 'enterprise', 'face', 'h', 'chips', 'arent', 'everyday', 'consumers', 'theyre', 'faceless', 'corporations', 'dish', 'billions', 'needed', 'train', 'large', 'language', 'models', 'therein', 'lies', 'nvidias', 'success', 'see', 'day', 'gtc', 'began', 'jensen', 'huang', 'held', 'meeting', 'investors', 'tell', 'company', 'poised', 'win', 'large', 'chunk', 'billion', 'corporations', 'spend', 'building', 'maintaining', 'data', 'centers', 'every', 'year', 'given', 'variety', 'hardware', 'software', 'nvidia', 'offer', 'well', 'good', 'company', 'theres', 'one', 'stakeholder', 'hopelessly', 'missing', 'nvidias', 'future', 'plans', 'gamers', 'nvidia', 'never', 'really', 'started', 'artificial', 'intelligence', 'company', 'way', 'openai', 'many', 'others', 'like', 'started', 'company', 'produced', 'graphic', 'cards', 'video', 'games', 'long', 'long', 'time', 'nvidia', 'known', 'offshoot', 'research', 'producing', 'better', 'better', 'graphic', 'cards', 'ended', 'creating', 'tensor', 'cores', 'realtime', 'deep', 'learning', 'image', 'enhancement', 'upscaling', 'technologies', 'use', 'video', 'games', 'little', 'nvidia', 'know', 'technology', 'would', 'serve', 'backbone', 'llms', 'instantly', 'transforming', 'arms', 'dealer', 'choice', 'corporations', 'pursuit', 'perfect', 'ai', 'nvidia', 'may', 'well', 'touch', 'roots', 'thats', 'hardly', 'shareholders', 'care', 'nvidia', 'shareholders', 'dont', 'care', 'gamers', 'nvidia', 'doesnt', 'care', 'gamers', 'conference', 'launch', 'companys', 'next', 'graphic', 'card', 'instantly', 'hijacked', 'talk', 'ai', 'ai', 'intents', 'purposes', 'sells', 'may', 'call', 'woodstock', 'ai', 'ill', 'call', 'death', 'knell', 'nvidias', 'days', 'gamingfocused', 'company', 'kill', 'two', 'birds', 'one', 'stone', 'dont', 'know', 'ask', 'satya', 'nadella', 'laserfocused', 'microsoft', 'chief', 'executive', 'monopolizing', 'companys', 'success', 'ai', 'decided', 'unthinkable', 'hire', 'competitors', 'staff', 'hand', 'reins', 'newly', 'launched', 'division', 'focused', 'primarily', 'artificial', 'intelligence', 'course', 'referring', 'mustafa', 'suleyman', 'karen', 'simonyan', 'cofounders', 'ai', 'startup', 'inflection', 'ai', 'rec ...

# %% [markdown]
# ##### 4. Data Transformation Techniques
# - Stemming
# - Lemmatization

# %%
def stem_words(tokens):
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokens]

stemmed_tokens = stem_words(filtered_tokens)
print(stemmed_tokens)
# Out:
# ['nvidia', 'throw', 'gamer', 'bu', 'ever', 'need', 'proof', 'nvidia', 'longer', 'compani', 'think', 'look', 'compani', 'recent', 'gpu', 'technolog', 'confer', 'also', 'known', 'gtc', 'confer', 'chockful', 'announc', 'big', 'one', 'cours', 'unveil', 'blackwel', 'class', 'ai', 'chip', 'supposedli', 'go', 'better', 'widelyindemand', 'equal', 'expens', 'hopper', 'processor', 'power', 'like', 'openai', 'chatgpt', 'demand', 'h', 'chip', 'transform', 'nvidia', 'compani', 'worth', 'trillion', 'almost', 'overnight', 'larger', 'scheme', 'thing', 'lead', 'includ', 'hackernoon', 'question', 'whether', 'stock', 'bubbl', 'almost', 'quarter', 'hackernoon', 'reader', 'thought', 'nvidia', 'prove', 'everyon', 'wrong', 'compani', 'last', 'earn', 'releas', 'show', 'still', 'sell', 'hopper', 'processor', 'sell', 'would', 'continu', 'near', 'futur', 'bring', 'us', 'nvidia', 'gtc', 'nvidia', 'chief', 'execut', 'jensen', 'huang', 'steve', 'job', 'certainli', 'sharehold', 'man', 'know', 'keep', 'happi', 'present', 'skill', 'damn', 'blackwel', 'announc', 'may', 'noth', 'akin', 'appl', 'unveil', 'first', 'iphon', 'boy', 'wall', 'street', 'go', 'crazi', 'crazi', 'come', 'worri', 'worri', 'monopoli', 'worri', 'suppli', 'worri', 'compani', 'may', 'produc', 'darn', 'ai', 'processor', 'fast', 'enough', 'nvidia', 'covid', 'demand', 'consum', 'desper', 'compani', 'charg', 'whatev', 'price', 'want', 'hardwar', 'ladi', 'gentlemen', 'futur', 'tech', 'compani', 'hope', 'began', 'aggress', 'hire', 'worldwid', 'pandem', 'find', 'demand', 'normal', 'world', 'open', 'make', 'nvidia', 'quit', 'possibl', 'compani', 'profit', 'consum', 'pandem', 'hit', 'even', 'bigger', 'jackpot', 'enterpris', 'face', 'h', 'chip', 'arent', 'everyday', 'consum', 'theyr', 'faceless', 'corpor', 'dish', 'billion', 'need', 'train', 'larg', 'languag', 'model', 'therein', 'lie', 'nvidia', 'success', 'see', 'day', 'gtc', 'began', 'jensen', 'huang', 'held', 'meet', 'investor', 'tell', 'compani', 'pois', 'win', 'larg', 'chunk', 'billion', 'corpor', 'spend', 'build', 'maintain', 'data', 'center', 'everi', 'year', 'given', 'varieti', 'hardwar', 'softwar', 'nvidia', 'offer', 'well', 'good', 'compani', 'there', 'one', 'stakehold', 'hopelessli', 'miss', 'nvidia', 'futur', 'plan', 'gamer', 'nvidia', 'never', 'realli', 'start', 'artifici', 'intellig', 'compani', 'way', 'openai', 'mani', 'other', 'like', 'start', 'compani', 'produc', 'graphic', 'card', 'video', 'game', 'long', 'long', 'time', 'nvidia', 'known', 'offshoot', 'research', 'produc', 'better', 'better', 'graphic', 'card', 'end', 'creat', 'tensor', 'core', 'realtim', 'deep', 'learn', 'imag', 'enhanc', 'upscal', 'technolog', 'use', 'video', 'game', 'littl', 'nvidia', 'know', 'technolog', 'would', 'serv', 'backbon', 'llm', 'instantli', 'transform', 'arm', 'dealer', 'choic', 'corpor', 'pursuit', 'perfect', 'ai', 'nvidia', 'may', 'well', 'touch', 'root', 'that', 'hardli', 'sharehold', 'care', 'nvidia', 'sharehold', 'dont', 'care', 'gamer', 'nvidia', 'doesnt', 'care', 'gamer', 'confer', 'launch', 'compani', 'next', 'graphic', 'card', 'instantli', 'hijack', 'talk', 'ai', 'ai', 'intent', 'purpos', 'sell', 'may', 'call', 'woodstock', 'ai', 'ill', 'call', 'death', 'knell', 'nvidia', 'day', 'gamingfocus', 'compani', 'kill', 'two', 'bird', 'one', 'stone', 'dont', 'know', 'ask', 'satya', 'nadella', 'laserfocus', 'microsoft', 'chief', 'execut', 'monopol', 'compani', 'success', 'ai', 'decid', 'unthink', 'hire', 'competitor', 'staff', 'hand', 'rein', 'newli', 'launch', 'divis', 'focus', 'primarili', 'artifici', 'intellig', 'cours', 'refer', 'mustafa', 'suleyman', 'karen', 'simonyan', 'cofound', 'ai', 'startup', 'inflect', 'ai', 'recent', 'compet', 'microsoft', 'ward', 'openai', 'found', 'offer', 'assum', 'could', 'refus', 'ye', 'mustafa', 'suleyman', 'cofound', 'deepmind', 'technolog', 'sold', 'googl', 'lead', 'microsoft', 'ai', 'chief', 'execut', 'help', 'karen', 'simonyan', 'divis', 'chief', 'scientist', 'microsoft', 'also', 'seem', 'hire', 'sever', 'member' ...

# %%
def lemmatize_words(tokens):
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(word) for word in tokens]

lemmatized_tokens = lemmatize_words(filtered_tokens)
print(lemmatized_tokens)
# Out:
# ['nvidia', 'throw', 'gamers', 'bus', 'ever', 'needed', 'proof', 'nvidia', 'longer', 'company', 'think', 'look', 'company', 'recent', 'gpu', 'technology', 'conference', 'also', 'known', 'gtc', 'conference', 'chockfull', 'announcement', 'big', 'one', 'course', 'unveiling', 'blackwell', 'class', 'ai', 'chip', 'supposedly', 'going', 'better', 'widelyindemand', 'equally', 'expensive', 'hopper', 'processor', 'powered', 'like', 'openais', 'chatgpt', 'demand', 'h', 'chip', 'transformed', 'nvidia', 'company', 'worth', 'trillion', 'almost', 'overnight', 'larger', 'scheme', 'thing', 'leading', 'including', 'hackernoon', 'question', 'whether', 'stock', 'bubble', 'almost', 'quarter', 'hackernoon', 'reader', 'thought', 'nvidia', 'prove', 'everyone', 'wrong', 'company', 'last', 'earnings', 'release', 'showed', 'still', 'selling', 'hopper', 'processor', 'selling', 'would', 'continue', 'near', 'future', 'brings', 'u', 'nvidia', 'gtc', 'nvidia', 'chief', 'executive', 'jensen', 'huang', 'steve', 'job', 'certainly', 'shareholder', 'man', 'know', 'keep', 'happy', 'presentation', 'skill', 'damned', 'blackwell', 'announcement', 'may', 'nothing', 'akin', 'apple', 'unveiling', 'first', 'iphone', 'boy', 'wall', 'street', 'go', 'crazy', 'crazy', 'come', 'worry', 'worry', 'monopoly', 'worry', 'supply', 'worry', 'company', 'may', 'producing', 'darn', 'ai', 'processor', 'fast', 'enough', 'nvidia', 'covid', 'demand', 'consumer', 'desperate', 'company', 'charge', 'whatever', 'price', 'want', 'hardware', 'lady', 'gentleman', 'future', 'tech', 'company', 'hoped', 'began', 'aggressively', 'hiring', 'worldwide', 'pandemic', 'find', 'demand', 'normalizing', 'world', 'opened', 'make', 'nvidia', 'quite', 'possibly', 'company', 'profiteered', 'consumer', 'pandemic', 'hit', 'even', 'bigger', 'jackpot', 'enterprise', 'face', 'h', 'chip', 'arent', 'everyday', 'consumer', 'theyre', 'faceless', 'corporation', 'dish', 'billion', 'needed', 'train', 'large', 'language', 'model', 'therein', 'lie', 'nvidias', 'success', 'see', 'day', 'gtc', 'began', 'jensen', 'huang', 'held', 'meeting', 'investor', 'tell', 'company', 'poised', 'win', 'large', 'chunk', 'billion', 'corporation', 'spend', 'building', 'maintaining', 'data', 'center', 'every', 'year', 'given', 'variety', 'hardware', 'software', 'nvidia', 'offer', 'well', 'good', 'company', 'there', 'one', 'stakeholder', 'hopelessly', 'missing', 'nvidias', 'future', 'plan', 'gamers', 'nvidia', 'never', 'really', 'started', 'artificial', 'intelligence', 'company', 'way', 'openai', 'many', 'others', 'like', 'started', 'company', 'produced', 'graphic', 'card', 'video', 'game', 'long', 'long', 'time', 'nvidia', 'known', 'offshoot', 'research', 'producing', 'better', 'better', 'graphic', 'card', 'ended', 'creating', 'tensor', 'core', 'realtime', 'deep', 'learning', 'image', 'enhancement', 'upscaling', 'technology', 'use', 'video', 'game', 'little', 'nvidia', 'know', 'technology', 'would', 'serve', 'backbone', 'llm', 'instantly', 'transforming', 'arm', 'dealer', 'choice', 'corporation', 'pursuit', 'perfect', 'ai', 'nvidia', 'may', 'well', 'touch', 'root', 'thats', 'hardly', 'shareholder', 'care', 'nvidia', 'shareholder', 'dont', 'care', 'gamers', 'nvidia', 'doesnt', 'care', 'gamers', 'conference', 'launch', 'company', 'next', 'graphic', 'card', 'instantly', 'hijacked', 'talk', 'ai', 'ai', 'intent', 'purpose', 'sell', 'may', 'call', 'woodstock', 'ai', 'ill', 'call', 'death', 'knell', 'nvidias', 'day', 'gamingfocused', 'company', 'kill', 'two', 'bird', 'one', 'stone', 'dont', 'know', 'ask', 'satya', 'nadella', 'laserfocused', 'microsoft', 'chief', 'executive', 'monopolizing', 'company', 'success', 'ai', 'decided', 'unthinkable', 'hire', 'competitor', 'staff', 'hand', 'rein', 'newly', 'launched', 'division', 'focused', 'primarily', 'artificial', 'intelligence', 'course', 'referring', 'mustafa', 'suleyman', 'karen', 'simonyan', 'cofounder', 'ai', 'startup', 'inflection', 'ai', 'recently', 'competing', 'microsofts', 'ward', 'openai', 'found', ...

# %% [markdown]
# ##### 5. Data Enrichment Techniques
# - Part-of-Speech Tagging (PoS)
# - Word Sense Disambiguation
# - Noun Phrase Extraction
# - Named-entity Recognition

# %%
def pos_tagging(tokens):
    pos_tag = nltk.pos_tag(tokens)
    pos_tagged_noun_verb = []
    for word, tag in pos_tag:
        if tag in ["NN", "NNP", "NNS", "VB", "VBD", "VBG", "VBN", "VBP", "VBZ"]:
            pos_tagged_noun_verb.append((word, tag))
    return pos_tagged_noun_verb

pos_tagged_text = pos_tagging(lemmatized_tokens)
print(pos_tagged_text)
# Out:
# [('throw', 'NN'), ('gamers', 'NNS'), ('bus', 'VBP'), ('needed', 'VBN'), ('proof', 'NN'), ('nvidia', 'NN'), ('company', 'NN'), ('think', 'VBP'), ('look', 'NN'), ('company', 'NN'), ('gpu', 'NN'), ('technology', 'NN'), ('conference', 'NN'), ('known', 'VBN'), ('conference', 'NN'), ('chockfull', 'NN'), ('announcement', 'NN'), ('course', 'NN'), ('unveiling', 'VBG'), ('class', 'NN'), ('ai', 'NN'), ('chip', 'NN'), ('going', 'VBG'), ('widelyindemand', 'VB'), ('hopper', 'NN'), ('processor', 'NN'), ('powered', 'VBN'), ('openais', 'NN'), ('demand', 'NN'), ('h', 'NN'), ('chip', 'NN'), ('transformed', 'VBD'), ('company', 'NN'), ('worth', 'NN'), ('thing', 'NN'), ('leading', 'VBG'), ('including', 'VBG'), ('question', 'NN'), ('stock', 'NN'), ('quarter', 'NN'), ('hackernoon', 'NN'), ('reader', 'NN'), ('thought', 'VBD'), ('everyone', 'NN'), ('company', 'NN'), ('earnings', 'NNS'), ('release', 'NN'), ('showed', 'VBD'), ('selling', 'VBG'), ('processor', 'NN'), ('selling', 'NN'), ('continue', 'VB'), ('brings', 'NNS'), ('gtc', 'NN'), ('executive', 'NN'), ('jensen', 'NN'), ('huang', 'VBD'), ('job', 'NN'), ('shareholder', 'NN'), ('man', 'NN'), ('know', 'VBP'), ('keep', 'VB'), ('presentation', 'NN'), ('skill', 'NN'), ('damned', 'VBN'), ('announcement', 'NN'), ('nothing', 'NN'), ('akin', 'VB'), ('apple', 'NN'), ('unveiling', 'VBG'), ('iphone', 'NN'), ('boy', 'NN'), ('wall', 'NN'), ('street', 'NN'), ('go', 'VBP'), ('come', 'VBN'), ('worry', 'NN'), ('worry', 'VBP'), ('monopoly', 'NN'), ('worry', 'VBP'), ('supply', 'NN'), ('worry', 'VBP'), ('company', 'NN'), ('producing', 'VBG'), ('darn', 'VB'), ('processor', 'NN'), ('nvidia', 'NN'), ('demand', 'NN'), ('consumer', 'NN'), ('company', 'NN'), ('charge', 'NN'), ('price', 'NN'), ('want', 'VBP'), ('hardware', 'NN'), ('future', 'NN'), ('tech', 'NN'), ('company', 'NN'), ('hoped', 'VBD'), ('began', 'VBD'), ('hiring', 'VBG'), ('find', 'NN'), ('demand', 'NN'), ('normalizing', 'VBG'), ('world', 'NN'), ('opened', 'VBD'), ('make', 'VBP'), ('quite', 'NN'), ('company', 'NN'), ('profiteered', 'VBD'), ('consumer', 'NN'), ('pandemic', 'NN'), ('hit', 'VBD'), ('jackpot', 'NN'), ('enterprise', 'NN'), ('face', 'NN'), ('h', 'NN'), ('chip', 'NN'), ('consumer', 'NN'), ('theyre', 'NN'), ('faceless', 'NN'), ('corporation', 'NN'), ('needed', 'VBN'), ('train', 'NN'), ('language', 'NN'), ('model', 'NN'), ('lie', 'VBZ'), ('success', 'NN'), ('see', 'VBP'), ('day', 'NN'), ('gtc', 'VB'), ('began', 'VBD'), ('huang', 'NN'), ('held', 'VBD'), ('meeting', 'VBG'), ('investor', 'NN'), ('tell', 'NN'), ('company', 'NN'), ('poised', 'VBD'), ('win', 'VB'), ('chunk', 'NN'), ('corporation', 'NN'), ('spend', 'VB'), ('building', 'NN'), ('maintaining', 'VBG'), ('data', 'NNS'), ('center', 'NN'), ('year', 'NN'), ('given', 'VBN'), ('variety', 'NN'), ('hardware', 'NN'), ('software', 'NN'), ('nvidia', 'NN'), ('offer', 'NN'), ('company', 'NN'), ('stakeholder', 'NN'), ('missing', 'VBG'), ('future', 'NN'), ('plan', 'NN'), ('gamers', 'NNS'), ('nvidia', 'VBP'), ('started', 'VBN'), ('intelligence', 'NN'), ('company', 'NN'), ('way', 'NN'), ('openai', 'VBD'), ('others', 'NNS'), ('started', 'VBN'), ('company', 'NN'), ('produced', 'VBD'), ('card', 'NN'), ('video', 'NN'), ('game', 'NN'), ('time', 'NN'), ('known', 'VBN'), ('research', 'NN'), ('producing', 'VBG'), ('card', 'NN'), ('ended', 'VBD'), ('creating', 'VBG'), ('tensor', 'NN'), ('core', 'NN'), ('realtime', 'NN'), ('learning', 'NN'), ('image', 'NN'), ('upscaling', 'VBG'), ('technology', 'NN'), ('use', 'NN'), ('video', 'NN'), ('game', 'NN'), ('know', 'VBP'), ('technology', 'NN'), ('serve', 'VB'), ('backbone', 'NN'), ('llm', 'NN'), ('transforming', 'VBG'), ('arm', 'NN'), ('dealer', 'NN'), ('choice', 'NN'), ('corporation', 'NN'), ('pursuit', 'NN'), ('perfect', 'NN'), ('nvidia', 'NN'), ('touch', 'VB'), ('root', 'NN'), ('thats', 'NNS'), ('shareholder', 'NN'), ('care', 'NN'), ('shareholder', 'NN'), ('dont', 'NN'), ('care', 'NN'), ('gamers', 'NNS'), ('nvidia', 'VBP'), ('doesnt', 'NN'), ('care', 'NN'), ('gamers', 'NNS'), ('co ...

# %%
def named_entity_recognition(text):
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
   
    ne_tree = ne_chunk(pos_tags)

    named_entities = []
    for subtree in ne_tree:
        if isinstance(subtree, Tree):
            entity_type = subtree.label()
            entity_value = " ".join([word for word, tag in subtree.leaves()])
            named_entities.append((entity_type, entity_value))
   
    return named_entities

named_entity_text = named_entity_recognition(ARTICLE)
print("\nNamed entities found:")
print(named_entity_text)
# Out:
# Named entities found:
# [('GPE', 'Nvidia'), ('PERSON', 'Throws Gamers'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'GPU Technology Conference'), ('ORGANIZATION', 'GTC'), ('ORGANIZATION', 'Blackwell'), ('ORGANIZATION', 'AI'), ('GPE', 'Hopper'), ('ORGANIZATION', 'OpenAI'), ('ORGANIZATION', 'ChatGPT'), ('ORGANIZATION', 'H100'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'HackerNoon'), ('ORGANIZATION', 'HackerNoon'), ('PERSON', 'Nvidia'), ('ORGANIZATION', 'Hopper'), ('PERSON', 'Which'), ('ORGANIZATION', 'Nvidia'), ('PERSON', 'Nvidia Chief Executive Jensen Huang'), ('PERSON', 'Steve Jobs'), ('ORGANIZATION', 'Blackwell'), ('PERSON', 'Apple'), ('ORGANIZATION', 'iPhone'), ('FACILITY', 'Wall Street'), ('GPE', 'Nvidia'), ('PERSON', 'Which'), ('GPE', 'Nvidia'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'GTC'), ('PERSON', 'Jensen Huang'), ('GPE', 'Nvidia'), ('GPE', 'Nvidia'), ('PERSON', 'Nvidia'), ('ORGANIZATION', 'OpenAI'), ('PERSON', 'Nvidia'), ('PERSON', 'Little'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'LLMs'), ('PERSON', 'Nvidia'), ('GPE', 'Nvidia'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'AI'), ('ORGANIZATION', 'AI'), ('ORGANIZATION', 'AI'), ('GPE', 'Nvidia'), ('PERSON', 'Ask Satya Nadella'), ('ORGANIZATION', 'Microsoft'), ('GPE', 'AI'), ('PERSON', 'Mustafa Suleyman'), ('PERSON', 'Karen Simonyan'), ('ORGANIZATION', 'AI'), ('PERSON', 'Microsoft'), ('PERSON', 'Mustafa Suleyman'), ('ORGANIZATION', 'DeepMind Technologies'), ('GPE', 'Google'), ('PERSON', 'Microsoft AI'), ('PERSON', 'Karen Simonyan'), ('PERSON', 'Microsoft'), ('ORGANIZATION', 'Inflection'), ('PERSON', 'Suleyman'), ('PERSON', 'Simonyan'), ('ORGANIZATION', 'Copilot'), ('ORGANIZATION', 'Inflection'), ('PERSON', 'Microsoft'), ('ORGANIZATION', 'OpenAI'), ('PERSON', 'Sam Altman'), ('PERSON', 'Microsoft'), ('PERSON', 'Microsoft'), ('ORGANIZATION', 'HackerNoon'), ('ORGANIZATION', 'Tech Company'), ('PERSON', 'Google'), ('PERSON', 'Apple'), ('ORGANIZATION', 'microLED'), ('ORGANIZATION', 'Apple Watch'), ('PERSON', 'Apple Vision Pro'), ('PERSON', 'Apple'), ('ORGANIZATION', 'HackerNoon'), ('ORGANIZATION', 'Tech Company'), ('ORGANIZATION', 'Sheharyar Khan'), ('PERSON', 'Editor'), ('ORGANIZATION', 'Business Tech'), ('ORGANIZATION', 'HackerNoon'), ('ORGANIZATION', 'Tech Company Rankings'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'GPU Technology Conference'), ('ORGANIZATION', 'GTC'), ('ORGANIZATION', 'Blackwell'), ('ORGANIZATION', 'AI'), ('GPE', 'Hopper'), ('ORGANIZATION', 'OpenAI'), ('ORGANIZATION', 'ChatGPT'), ('ORGANIZATION', 'H100'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'HackerNoon'), ('ORGANIZATION', 'HackerNoon'), ('PERSON', 'Nvidia'), ('ORGANIZATION', 'Hopper'), ('PERSON', 'Which'), ('ORGANIZATION', 'Nvidia'), ('PERSON', 'Nvidia Chief Executive Jensen Huang'), ('PERSON', 'Steve Jobs'), ('ORGANIZATION', 'Blackwell'), ('ORGANIZATION', 'iPhone'), ('FACILITY', 'Wall Street'), ('GPE', 'Nvidia'), ('PERSON', 'Which'), ('GPE', 'Nvidia'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'GTC'), ('PERSON', 'Jensen Huang'), ('GPE', 'Nvidia'), ('GPE', 'Nvidia'), ('PERSON', 'Nvidia'), ('ORGANIZATION', 'OpenAI'), ('PERSON', 'Nvidia'), ('PERSON', 'Little'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'LLMs'), ('PERSON', 'Nvidia'), ('GPE', 'Nvidia'), ('PERSON', 'Nvidia'), ('ORGANIZATION', 'AI'), ('ORGANIZATION', 'AI'), ('ORGANIZATION', 'AI'), ('GPE', 'Nvidia'), ('ORGANIZATION', 'HackerNoon'), ('PERSON', 'Tech Company News Brief'), ('ORGANIZATION', 'HackerNoon'), ('PERSON', 'Subscribe'), ('PERSON', 'Microsoft'), ('ORGANIZATION', 'Corporate Espionage'), ('PERSON', 'Ask Satya Nadella'), ('ORGANIZATION', 'Microsoft'), ('GPE', 'AI'), ('PERSON', 'Mustafa Suleyman'), ('PERSON', 'Karen Simonyan'), ('ORGANIZATION', 'AI'), ('ORGANIZATION', 'Microsoft'), ('PERSON', 'Mustafa Suleyman'), ('ORGANIZATION', 'DeepMind Technologies'), ('GPE', 'Google'), ('PERSON', 'Microsoft AI'), ('PERSON', 'Karen Simonyan'), ('PERSON', 'Microsoft'), ('ORGANIZATION', 'Inflection'), ('PERSON', 'Suleyman'), ('PERSON', 'Simonyan'), ('PERSON', 'Copilot'), ('ORGANIZATION', 'Inflection'), ('PERSON', 'Microsoft ...

# %%
def word_sense_disambiguation(sentence, word):
    return lesk(sentence, word)

sense_disambiguation = word_sense_disambiguation(ARTICLE, "nlp")
print(sense_disambiguation)
# Out:
# Synset('natural_language_processing.n.01')

# %%
def noun_phrase_extraction(text):
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    noun_phrases = []
    current_phrase = []
    for word, tag in pos_tags: 
        if tag.startswith('NN') or tag.startswith('JJ'):
            current_phrase.append(word)
        else:
            if current_phrase:
                noun_phrases.append(' '.join(current_phrase))
                current_phrase = []
    # Add the last phrase if it exists
    if current_phrase:
        noun_phrases.append(' '.join(current_phrase))
    return noun_phrases

noun_phrases = noun_phrase_extraction(ARTICLE)

print("Extracted noun phrases:")
for np in noun_phrases:
    print(f"- {np}")
# Out:
# Extracted noun phrases:
# - Nvidia Throws Gamers
# - Bus
# - proof
# - Nvidia
# - company
# - further
# - company
# - recent GPU Technology Conference
# - GTC
# - conference
# - chock-full
# - announcements
# - big
# - course
# - unveiling
# - Blackwell class
# - AI chips
# - better
# - widely-in-demand
# - expensive
# - Hopper processors
# - likes
# - OpenAI
# - ChatGPT
# - demand
# - H100 chips
# - Nvidia
# - company worth
# - larger scheme
# - things
# - HackerNoon
# - stock
# - bubble
# - quarter
# - HackerNoon readers
# - Nvidia
# - everyone wrong
# - company
# - last earnings release
# - Hopper processors
# - more
# - near future
# - Which
# - Nvidia GTC
# - Nvidia Chief Executive Jensen Huang
# - Steve Jobs
# - shareholders
# - man
# - happy – presentation skills
# - Blackwell announcement
# - nothing akin
# - Apple
# - unveiling
# - first iPhone
# - Wall Street
# - crazy
# - crazy
# - monopoly
# - supply
# - company
# - darn AI processors
# - Nvidia
# - COVID-19
# - demand
# - consumers
# - desperate
# - company
# - price
# - hardware
# - ladies
# - gentlemen
# - future tech companies
# - worldwide
# - demand
# - world
# - Which
# - Nvidia
# - only company
# - consumers
# - pandemic
# - bigger jackpot
# - enterprise
# - face
# - H100 chips
# - everyday consumers
# - faceless corporations
# - billions
# - large language models
# - therein
# - Nvidia
# - success
# - day
# - GTC
# - Jensen Huang
# - meeting
# - investors
# - company
# - large chunk
# - corporations
# - building
# - data centers
# - year
# - variety
# - hardware
# - software Nvidia
# - offer
# - good
# - company
# - stakeholder
# - Nvidia
# - future plans
# - gamers
# - Nvidia
# - artificial intelligence company
# - way OpenAI
# - many others
# - company
# - graphic cards
# - video games
# - long
# - long time
# - Nvidia
# - offshoot
# - research
# - better
# - better graphic cards
# - tensor cores
# - real-time deep learning image enhancement
# - upscaling technologies
# - use
# - video games
# - Little
# - Nvidia
# - technology
# - backbone
# - LLMs
# - arms dealer
# - choice
# - corporations
# - pursuit
# - perfect AI
# - Nvidia
# - touch
# - roots
# - shareholders
# - Nvidia shareholders
# - gamers
# - Nvidia
# - gamers
# - conference
# - launch
# - company
# - next graphic card
# - talk
# - AI
# - AI
# - intents
# - purposes
# - 'Woodstock
# - AI
# - death knell
# - Nvidia
# - days
# - gaming-focused company
# - birds
# - stone
# - Ask Satya Nadella
# - laser-focused
# - Microsoft chief executive
# - company
# - success
# - AI
# - unthinkable
# - competitor
# - staff
# - hand
# - reins
# - division
# - artificial intelligence
# - course
# - Mustafa Suleyman
# - Karen Simonyan
# - co-founders
# - AI startup Inflection AI
# - Microsoft
# - ward OpenAI
# - offer
# - same Mustafa Suleyman
# - DeepMind Technologies
# - Google
# - Microsoft AI
# - chief executive
# - help
# - Karen Simonyan
# - division
# - chief scientist
# - Microsoft
# - several members
# - Inflection team
# - Suleyman
# - Simonyan
# - company
# - Copilot
# - other consumer AI products
# - research
# - Inflection AI
# - return
# - whopping
# - prestige
# - Microsoft
# - lot
# - money
# - competitor
# - way
# - OpenAI
# - extension
# - Sam Altman
# - check
# - world
# - valuable company
# - Microsoft
# - anything
# - Microsoft
# - HackerNoon
# - Tech Company Rankingsthis week
# - Google
# - spot
# - First
# - electric car
# - smartwatch displays
# - period
# - realignment
# - Apple
# - company
# - plug
# - own smartwatch displays due
# - cost
# - complexity
# - microLED displays
# - due
# - future version
# - Apple Watch
# - part
# - push
# - company
# - reliance
# - partners
# - company
# - technology
# - house
# - Apple Vision Pro
# - s
# - electric car
# - decision
# - plug
# - elimination
# - job roles
# - company
# - Apple
# - HackerNoon
# - Tech Company Rankingsthis week
# - wrap
# - share
# - newsletter
# - family
# - friends
# - y'all next week
# - PEACE
# - ☮️ — Sheharyar Khan
# - Editor
# - Business Tech @ HackerNoon * All rankings
# - current
# - Monday
# - rankings
# - HackerNoon
# - Tech Company Rankings page ..
# - proof
# - Nvidia
# - company
# - further
# - company
# - apos
# - recent GPU Technology Conference
# - GTC
# - conference
# - chock-full
# - announcements
# - big
# - course
# - unveiling
# - Blackwell class
# - AI chips
# - better
# - widely-in-demand
# - expensive
# - Hopper processors
# - likes
# - OpenAI
# - apos
# - ChatGPT
# - demand
# - H100 chips
# - Nvidia
# - company worth
# - larger scheme
# - things
# - HackerNoon
# - stock
# - bubble
# - quarter
# - HackerNoon readers
# - Nvidia
# - everyone wrong
# - company
# - apos
# - last earnings release
# - Hopper processors
# - more
# - near future
# - Which
# - Nvidia GTC
# - Nvidia Chief Executive Jensen Huang
# - Steve Jobs
# - shareholders
# - apos
# - man
# - happy – presentation skills
# - Blackwell announcement
# - nothing akin
# - Apple
# - apos
# - unveiling
# - first iPhone
# - Wall Street
# - crazy
# - crazy
# - monopoly
# - supply
# - company
# - darn AI processors
# - Nvidia
# - COVID-19
# - demand
# - consumers
# - desperate
# - company
# - price
# - hardware
# - ladies
# - gentlemen
# - future tech companies
# - worldwide
# - demand
# - world
# - Which
# - Nvidia
# - only company
# - consumers
# - pandemic
# - bigger jackpot
# - enterprise
# - face
# - H100 chips
# - t
# - everyday consumers
# - re
# - faceless corporations
# - billions
# - large language models
# - therein
# - Nvidia
# - apos
# - s success
# - day
# - GTC
# - Jensen Huang
# - meeting
# - investors
# - company
# - large chunk
# - corporations
# - building
# - data centers
# - year
# - variety
# - hardware
# - software Nvidia
# - offer
# - good
# - company
# - apos
# - stakeholder
# - Nvidia
# - apos
# - future plans
# - gamers
# - Nvidia
# - artificial intelligence company
# - way OpenAI
# - many others
# - company
# - graphic cards
# - video games
# - long
# - long time
# - Nvidia
# - offshoot
# - research
# - better
# - better graphic cards
# - tensor cores
# - real-time deep learning image enhancement
# - upscaling technologies
# - use
# - video games
# - Little
# - Nvidia
# - technology
# - backbone
# - LLMs
# - arms dealer
# - choice
# - corporations
# - apos
# - pursuit
# - perfect AI
# - Nvidia
# - touch
# - roots
# - apos
# - shareholders
# - Nvidia shareholders
# - gamers
# - Nvidia doesn
# - apos
# - gamers
# - conference
# - launch
# - company
# - apos
# - next graphic card
# - talk
# - AI
# - s
# - AI
# - intents
# - purposes
# - apos
# - Woodstock
# - AI
# - apos
# - apos
# - death knell
# - Nvidia
# - apos
# - s days
# - gaming-focused company
# - 👋
# - re reading HackerNoon
# - apos
# - Tech Company News Brief
# - weekly collection
# - tech goodness
# - HackerNoon
# - apos
# - proprietary data
# - internet trends
# - companies
# - public consciousness
# - Subscribe
# - complete newsletter
# - inbox
# - Tuesday
# - Microsoft
# - Corporate Espionage
# - Lifetime How
# - birds
# - stone
# - t
# - Ask Satya Nadella
# - laser-focused
# - Microsoft chief executive
# - company
# - apos
# - s success
# - AI
# - unthinkable
# - competitor
# - apos
# - s staff
# - hand
# - reins
# - division
# - artificial intelligence
# - course
# - Mustafa Suleyman
# - Karen Simonyan
# - co-founders
# - AI startup Inflection AI
# - Microsoft
# - apos
# - ward OpenAI
# - offer
# - same Mustafa Suleyman
# - DeepMind Technologies
# - Google
# - Microsoft AI
# - chief executive
# - help
# - Karen Simonyan
# - division
# - apos
# - chief scientist
# - Microsoft
# - several members
# - quot
# - Inflection team
# - Suleyman
# - Simonyan
# - company
# - apos
# - Copilot
# - other consumer AI products
# - research
# - Inflection AI
# - return
# - whopping
# - prestige
# - Microsoft
# - apos
# - lot
# - money
# - competitor
# - way
# - OpenAI
# - extension
# - Sam Altman
# - check
# - world
# - apos
# - valuable company
# - Microsoft
# - anything
# - Microsoft
# - HackerNoon
# - apos
# - Tech Company Rankingsthis week
# - Google
# - spot
# - Apple Pulls
# - Plug
# - In-House MicroLED Displays First
# - electric car
# - smartwatch displays
# - period
# - realignment
# - Apple
# - company
# - plug
# - own smartwatch displays due
# - cost
# - complexity
# - microLED displays
# - due
# - future version
# - Apple Watch
# - part
# - push
# - company
# - apos
# - s reliance
# - partners
# - company
# - technology
# - house
# - Apple Vision Pro
# - s
# - electric car
# - decision
# - plug
# - elimination
# - job roles
# - company
# - Apple
# - HackerNoon
# - apos
# - Tech Company Rankingsthis week
# - Other News .. 📰 SEC Seeks
# - Fine
# - Final Judgment Against Ripple —
# - CoinDesk AI
# - data problem
# - Cyera
# - valuation
# - —
# - TechCrunch
# - ways Apple ’
# - monopoly lawsuit
# - iPhone experience
# - fans —
# - CNN Musk
# - apos
# - X Corp
# - lawsuit
# - hate speech watchdog —
# - Reuters Meta
# - apos
# - broad-brush ban
# - Islamic term
# - free speech
# - board rules
# - Axios Adam Neumann
# - bid
# - WeWork
# - financing
# - diligence firm
# - CNBC
# - apos
# - wrap
# - Don
# - apos
# - share
# - newsletter
# - family
# - friends
# - See y
# - apos
# - next week
# - PEACE
# - ☮️ — Sheharyar Khan
# - Editor
# - Business Tech @ HackerNoon * All rankings
# - current
# - Monday
# - rankings
# - visit HackerNoon
# - apos
# - Tech Company Rankings page
# - proof
# - Nvidia
# - company
# - further
# - company
# - apos
# - recent GPU Technology Conference
# - GTC
# - conference
# - chock-full
# - announcements
# - big
# - course
# - unveiling
# - Blackwell class
# - AI chips
# - better
# - widely-in-demand
# - expensive
# - Hopper processors
# - likes
# - OpenAI
# - apos
# - ChatGPT
# - Nvidia Nvidia
# - demand
# - H100 chips
# - Nvidia
# - company worth
# - larger scheme
# - things
# - HackerNoon
# - stock
# - bubble
# - quarter
# - HackerNoon readers
# - Nvidia
# - everyone wrong
# - company
# - apos
# - last earnings release
# - Hopper processors
# - more
# - near future
# - question question
# - continue
# - Which
# - Nvidia GTC
# - Nvidia Chief Executive Jensen Huang
# - Steve Jobs
# - shareholders
# - apos
# - man
# - happy – presentation skills
# - Blackwell announcement
# - nothing akin
# - Apple
# - apos
# - unveiling
# - first iPhone
# - Wall Street
# - crazy
# - crazy
# - monopoly
# - supply
# - company
# - darn AI processors
# - Nvidia
# - COVID-19
# - demand
# - consumers
# - desperate
# - company
# - price
# - hardware
# - ladies
# - gentlemen
# - future tech companies
# - worldwide
# - demand
# - world
# - Which
# - Nvidia
# - only company
# - consumers
# - pandemic
# - bigger jackpot
# - enterprise
# - face
# - H100 chips
# - t
# - everyday consumers
# - re
# - faceless corporations
# - billions
# - large language models
# - therein
# - Nvidia
# - apos
# - s success
# - day
# - GTC
# - Jensen Huang
# - meeting
# - investors
# - company
# - large chunk
# - corporations
# - building
# - data centers
# - year
# - variety
# - hardware
# - software Nvidia
# - offer
# - meeting
# - good
# - company
# - apos
# - stakeholder
# - Nvidia
# - apos
# - future plans
# - gamers
# - Nvidia
# - artificial intelligence company
# - way OpenAI
# - many others
# - company
# - graphic cards
# - video games
# - long
# - long time
# - Nvidia
# - offshoot
# - research
# - better
# - better graphic cards
# - tensor cores
# - real-time deep learning image enhancement
# - upscaling technologies
# - use
# - video games
# - Little
# - Nvidia
# - technology
# - backbone
# - LLMs
# - arms dealer
# - choice
# - corporations
# - apos
# - pursuit
# - perfect AI
# - Nvidia
# - touch
# - roots
# - apos
# - shareholders
# - Nvidia shareholders
# - gamers
# - Nvidia doesn
# - apos
# - gamers
# - conference
# - launch
# - company
# - apos
# - next graphic card
# - talk
# - AI
# - s
# - AI
# - intents
# - purposes
# - apos
# - Woodstock
# - AI
# - apos
# - apos
# - death knell
# - Nvidia
# - apos
# - s days
# - gaming-focused company
# - Woodstock
# - AI Woodstock
# - AI 👋
# - re reading HackerNoon
# - apos
# - Tech Company News Brief
# - weekly collection
# - tech goodness
# - HackerNoon
# - apos
# - proprietary data
# - internet trends
# - companies
# - public consciousness
# - Subscribe
# - complete newsletter
# - inbox
# - Tuesday
# - re reading HackerNoon
# - apos
# - Tech Company News Brief
# - weekly collection
# - tech goodness
# - HackerNoon
# - apos
# - proprietary data
# - internet trends
# - companies
# - public consciousness
# - Subscribe
# - complete newsletter
# - inbox
# - Tuesday
# - re reading HackerNoon
# - apos
# - Tech Company News Brief
# - weekly collection
# - tech goodness
# - HackerNoon
# - apos
# - proprietary data
# - internet trends
# - companies
# - public consciousness
# - Subscribe
# - complete newsletter
# - inbox
# - Tuesday
# - Tech Company News Brief Tech Company News Brief
# - complete Microsoft Pulls
# - Corporate Espionage
# - Lifetime How
# - birds
# - stone
# - t
# - Ask Satya Nadella
# - laser-focused
# - Microsoft chief executive
# - company
# - apos
# - s success
# - AI
# - unthinkable
# - competitor
# - apos
# - s staff
# - hand
# - reins
# - division
# - artificial intelligence
# - Microsoft Microsoft
# - course
# - Mustafa Suleyman
# - Karen Simonyan
# - co-founders
# - AI startup Inflection AI
# - Microsoft
# - apos
# - ward OpenAI
# - offer
# - same Mustafa Suleyman
# - DeepMind Technologies
# - Google
# - Microsoft AI
# - chief executive
# - help
# - Karen Simonyan
# - division
# - apos
# - chief scientist
# - Google Google Microsoft
# - several members
# - quot
# - Inflection team
# - Suleyman
# - Simonyan
# - company
# - apos
# - Copilot
# - other consumer AI products
# - research
# - Inflection AI
# - return
# - whopping
# - prestige
# - Microsoft
# - apos
# - lot
# - money
# - competitor
# - way
# - OpenAI
# - extension
# - Sam Altman
# - check
# - world
# - apos
# - valuable company
# - Microsoft
# - anything
# - check
# - check Microsoft
# - HackerNoon
# - apos
# - Tech Company Rankings
# - week
# - Google
# - spot
# - Tech Company Rankings Tech Company Rankings Apple Pulls
# - Plug
# - In-House MicroLED Displays Apple Pulls
# - Plug
# - In-House MicroLED Displays First
# - electric car
# - smartwatch displays
# - electric car electric car
# - period
# - realignment
# - Apple
# - company
# - plug
# - own smartwatch displays due
# - cost
# - complexity
# - Apple Apple
# - plug
# - plug
# - microLED displays
# - due
# - future version
# - Apple Watch
# - part
# - push
# - company
# - apos
# - s reliance
# - partners
# - company
# - technology
# - house
# - Apple Vision Pro
# - s
# - electric car
# - decision
# - plug
# - elimination
# - job roles
# - company
# - Apple
# - HackerNoon
# - apos
# - Tech Company Rankings
# - week
# - Tech Company Rankings Tech Company Rankings
# - Other News .. 📰
# - Other News .. 📰 SEC Seeks
# - Fine
# - Final Judgment Against Ripple —
# - CoinDesk AI
# - data problem
# - Cyera
# - valuation
# - —
# - TechCrunch
# - ways Apple ’
# - monopoly lawsuit
# - iPhone experience
# - fans —
# - CNN Musk
# - apos
# - X Corp
# - lawsuit
# - hate speech watchdog —
# - Reuters Meta
# - apos
# - broad-brush ban
# - Islamic term
# - free speech
# - board rules
# - Axios Adam Neumann
# - bid
# - WeWork
# - financing
# - diligence firm
# - CNBC SEC Seeks
# - Fine
# - Final Judgment Against Ripple —
# - CoinDesk CoinDesk CoinDesk AI
# - data problem
# - Cyera
# - valuation
# - —
# - TechCrunch TechCrunch TechCrunch
# - ways Apple ’
# - monopoly lawsuit
# - iPhone experience
# - fans —
# - CNN CNN CNN Musk
# - apos
# - X Corp
# - lawsuit
# - hate speech watchdog —
# - Reuters Reuters Reuters Meta
# - apos
# - broad-brush ban
# - Islamic term
# - free speech
# - board rules
# - Axios Axios Axios Adam Neumann
# - bid
# - WeWork
# - financing
# - diligence firm
# - CNBC CNBC CNBC
# - apos
# - wrap
# - Don
# - apos
# - share
# - newsletter
# - family
# - friends
# - See y
# - apos
# - next week
# - PEACE
# - ☮️ — Sheharyar Khan
# - Editor
# - Business Tech @ HackerNoon * All rankings
# - current
# - Monday
# - rankings
# - visit HackerNoon
# - apos
# - Tech Company Rankings page
# - rankings
# - current
# - Monday
# - rankings
# - visit HackerNoon
# - apos
# - Tech Company Rankings page
# - rankings
# - current
# - Monday
# - rankings
# - visit HackerNoon
# - apos
# - Tech Company Rankings page
# - Tech Company Rankings Tech Company Rankings
